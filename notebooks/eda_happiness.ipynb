# %% [markdown]
# # ¿Qué hace felices a los países?
# ## Análisis exploratorio de los factores que explican la felicidad mundial en 2024
#
# ### Introducción
# La felicidad de una población es un concepto complejo en el que influyen factores económicos, sociales, políticos y de salud. En los últimos años, diferentes informes internacionales han intentado medir este bienestar subjetivo para entender por qué algunos países muestran niveles de satisfacción vital más altos que otros.
#
# En este proyecto se realizará un Análisis Exploratorio de Datos (EDA) a partir de un dataset internacional sobre felicidad, centrando el estudio en los datos correspondientes al año 2024. El objetivo no será solo describir qué países ocupan las primeras y últimas posiciones del ranking, sino también identificar qué variables parecen estar más relacionadas con un mayor nivel de felicidad.
#
# A través de este análisis se buscará detectar patrones, comparar comportamientos entre países y extraer conclusiones útiles sobre los principales factores asociados al bienestar. De esta forma, el proyecto combinará una parte descriptiva con una interpretación orientada a negocio y toma de decisiones.
#
# ### Objetivo general
# Analizar los datos de felicidad mundial de 2024 para identificar qué factores sociales, económicos y de calidad de vida están más relacionados con la puntuación de felicidad de los países, detectando patrones relevantes y diferencias entre los países con mejores y peores resultados.
#
# ### Hipótesis
# 1. Los países con mayor PIB per cápita tienden a presentar mayores niveles de felicidad.
#
# 2. El apoyo social es uno de los factores más influyentes en la felicidad de un país.
#
# 3. Una mayor esperanza de vida saludable está asociada con una mayor puntuación de felicidad.
#
# 4. Los países con mayor libertad para tomar decisiones vitales tienden a mostrar niveles más altos de felicidad.
#
# 5. Los países con mayores niveles de felicidad no destacan únicamente en una sola variable, sino en la combinación de varios factores favorables, como un mayor PIB per cápita, un fuerte apoyo social y una mejor esperanza de vida saludable.

# %% [markdown]
# ## Fuente de datos
#
# Para este proyecto se ha utilizado un dataset internacional sobre felicidad que recoge la puntuación de felicidad de distintos países y varios factores explicativos asociados al bienestar de la población.
#
# Entre las variables disponibles se encuentran la posición en el ranking, la puntuación de felicidad, el PIB per cápita, el apoyo social, la esperanza de vida saludable, la libertad para tomar decisiones vitales, la generosidad, la percepción de la corrupción y otras métricas complementarias.
#
# Este conjunto de datos permite estudiar no solo qué países presentan mayores niveles de felicidad, sino también qué factores parecen estar más relacionados con dichos resultados.
#
# ## Alcance del análisis
#
# Aunque el dataset contiene información de varios años, en este proyecto se ha decidido centrar el análisis en los registros correspondientes a 2024. De este modo, se trabaja con la información más reciente disponible y se evita mezclar contextos temporales diferentes que podrían dificultar la interpretación de los resultados.
#
# El análisis tendrá un enfoque exploratorio y estará orientado a identificar patrones, relaciones entre variables y diferencias entre países con mayores y menores niveles de felicidad.

# %% [markdown]
# ## Fuente de datos
#
# Para este proyecto se ha utilizado un dataset internacional sobre felicidad de los países, que recoge el ranking de felicidad y distintos factores explicativos asociados al bienestar de la población.
#
# El conjunto de datos incluye variables relacionadas con:
# - la puntuación de felicidad de cada país,
# - la posición en el ranking,
# - el PIB per cápita,
# - el apoyo social,
# - la esperanza de vida saludable,
# - la libertad para tomar decisiones vitales,
# - la generosidad,
# - la percepción de la corrupción,
# - y otras métricas complementarias.
#
# Este tipo de información permite analizar no solo qué países presentan mayores niveles de felicidad, sino también qué factores parecen estar más relacionados con esos resultados.
#
# ## Justificación del filtrado a 2024
#
# Aunque el dataset contiene información de varios años, en este análisis se ha decidido trabajar únicamente con los registros correspondientes a 2024.
#
# Esta decisión se toma por tres motivos principales:
#
# 1. Permite centrar el análisis en la situación más reciente disponible.
# 2. Evita mezclar contextos temporales diferentes que podrían distorsionar la interpretación.
# 3. Simplifica el análisis exploratorio, haciendo más clara la comparación entre países dentro de un mismo periodo.
#
# De este modo, el estudio se enfoca en ofrecer una fotografía actual del nivel de felicidad mundial y de los factores que mejor lo explican en el último año disponible.
#
# ## Primeras decisiones de preparación del dataset
#
# Antes de comenzar el análisis, se han tomado varias decisiones iniciales para preparar los datos:
#
# 1. Se carga el dataset completo y se revisa su estructura general, incluyendo número de filas, columnas, tipos de datos y valores nulos.
# 2. Se filtran únicamente los registros del año 2024 para construir un subconjunto de análisis más homogéneo.
# 3. Se comprueba la calidad de los datos resultantes tras el filtrado, revisando posibles valores ausentes o inconsistencias.
# 4. Se identifican las variables más relevantes para el análisis, especialmente aquellas relacionadas con la puntuación de felicidad y sus factores explicativos.
# 5. Se deja para fases posteriores la revisión de relaciones entre variables, detección de patrones, análisis de outliers y visualizaciones comparativas.
#
# Estas decisiones permiten construir una base sólida antes de avanzar hacia un análisis más profundo y visual.

# %% [markdown]
# ## Selección de la muestra de análisis
#
# Dado que el objetivo del proyecto es estudiar los factores asociados a la felicidad mundial en el contexto más reciente posible, se seleccionan únicamente los registros correspondientes al año 2024. A partir de este subconjunto se desarrollará el resto del análisis exploratorio.

# %% [markdown]
# ## Carga del dataset y revisión inicial
#
# En esta primera fase se carga el dataset completo para conocer su estructura general antes de aplicar cualquier filtro.
#
# El objetivo de esta revisión inicial es identificar:
# - el tamaño del conjunto de datos,
# - las variables disponibles,
# - los tipos de datos de cada columna,
# - y posibles problemas de calidad, como valores nulos o columnas con información incompleta.
#
# Esta exploración permitirá entender mejor el alcance del dataset y preparar la selección del subconjunto de análisis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 11


df = pd.read_csv('../src/data/happiness.csv')

# %%
# Vemos las primeras filas del dataframe 
df.head()
# Out:
#    Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0  2024     1      Finland         7.736         7.810         7.662
# 1  2023   143  Afghanistan         1.721         1.775         1.667
# 2  2022   137  Afghanistan         1.859         1.923         1.795
# 3  2021   146  Afghanistan         2.404         2.469         2.339
# 4  2020   150  Afghanistan         2.523         2.596         2.449
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.749                         1.783
# 1                             0.628                         0.000
# 2                             0.645                         0.000
# 3                             0.758                         0.000
# 4                             0.370                         0.000
#
#    Explained by: Healthy life expectancy  \
# 0                                  0.824
# 1                                  0.242
# ...

# %%
# Obtenemos información sobre el número de filas y columnas de el DataFrame de forma rápida y sencilla
df.shape
# Out:
# (1969, 13)

# %%
# Nombre de las columnas
df.columns
# Out:
# Index(['Year', 'Rank', 'Country name', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'Explained by: Log GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        1969 non-null   int64
#  1   Rank                                        1969 non-null   int64
#  2   Country name                                1969 non-null   str
#  3   Ladder score                                1969 non-null   float64
#  4   upperwhisker                                875 non-null    float64
#  5   lowerwhisker                                875 non-null    float64
#  6   Explained by: Log GDP per capita            872 non-null    float64
#  7   Explained by: Social support                872 non-null    float64
#  8   Explained by: Healthy life expectancy       870 non-null    float64
#  9   Explained by: Freedom to make life choices  871 non-null    float64
# ...

# %% [markdown]
# ### Primeras observaciones del dataset completo
#
# A partir de esta revisión inicial se observa que el dataset contiene información de varios años y combina una variable objetivo principal, la puntuación de felicidad (`Ladder score`), con varias variables explicativas relacionadas con economía, apoyo social, salud, libertad, generosidad y percepción de corrupción.
#
# Dado que el propósito del proyecto es estudiar la situación más reciente, no resulta necesario trabajar con toda la serie temporal para este análisis exploratorio inicial. Por ello, en el siguiente paso se construirá un subconjunto con los datos correspondientes exclusivamente al año 2024.

# %% [markdown]
# ## Selección de la muestra de análisis
#
# Como el objetivo del proyecto es analizar la situación más reciente posible, se seleccionan únicamente los registros correspondientes al año 2024.
#
# Esta decisión permite:
# - centrar el estudio en un único contexto temporal,
# - facilitar la comparación entre países,
# - y construir una fotografía actual del estado de la felicidad mundial.
#
# A partir de este subconjunto se desarrollará el resto del análisis exploratorio.

# %% [markdown]
# ## Selección de la muestra de análisis

# %%
df_2024 = df[df['Year'] == 2024]

df_2024.shape
# Out:
# (147, 13)

# %% [markdown]
# ## Revisión de calidad de los datos en 2024

# %%
df_2024.head()
# Out:
#     Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0   2024     1      Finland         7.736         7.810         7.662
# 13  2024     2      Denmark         7.521         7.611         7.431
# 26  2024     3      Iceland         7.515         7.606         7.425
# 45  2024     4       Sweden         7.345         7.427         7.262
# 58  2024     5  Netherlands         7.306         7.372         7.240
#
#     Explained by: Log GDP per capita  Explained by: Social support  \
# 0                              1.749                         1.783
# 13                             1.825                         1.748
# 26                             1.799                         1.840
# 45                             1.783                         1.698
# 58                             1.822                         1.667
#
#     Explained by: Healthy life expectancy  \
# 0                                   0.824
# 13                                  0.820
# ...

# %%
df_2024.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 147 entries, 0 to 1956
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        147 non-null    int64
#  1   Rank                                        147 non-null    int64
#  2   Country name                                147 non-null    str
#  3   Ladder score                                147 non-null    float64
#  4   upperwhisker                                147 non-null    float64
#  5   lowerwhisker                                147 non-null    float64
#  6   Explained by: Log GDP per capita            147 non-null    float64
#  7   Explained by: Social support                147 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
#  9   Explained by: Freedom to make life choices  146 non-null    float64
# ...

# %%
df_2024.describe()
# Out:
#          Year        Rank  Ladder score  upperwhisker  lowerwhisker  \
# count   147.0  147.000000    147.000000    147.000000    147.000000
# mean   2024.0   74.000000      5.578170      5.688701      5.467612
# std       0.0   42.579338      1.158278      1.148881      1.168702
# min    2024.0    1.000000      1.364000      1.427000      1.301000
# 25%    2024.0   37.500000      4.702500      4.828500      4.576500
# 50%    2024.0   74.000000      5.868000      5.965000      5.747000
# 75%    2024.0  110.500000      6.479000      6.570000      6.375000
# max    2024.0  147.000000      7.736000      7.810000      7.662000
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                        147.000000                    147.000000
# mean                           1.318701                      1.333395
# std                            0.393862                      0.349952
# min                            0.000000                      0.000000
# ...

# %%
df_2024.isnull().sum()
# Out:
# Year                                          0
# Rank                                          0
# Country name                                  0
# Ladder score                                  0
# upperwhisker                                  0
# lowerwhisker                                  0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    1
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       1
# Dystopia + residual                           3
# dtype: int64

# %% [markdown]
# ## Primeras decisiones de preparación del dataset
#
# Tras revisar el subconjunto de 2024, se toman las siguientes decisiones iniciales para preparar el análisis:
#
# 1. Se trabajará con los registros del año 2024 como muestra principal del proyecto.
# 2. La variable principal de estudio será `Ladder score`, ya que representa el nivel de felicidad de cada país.
# 3. Se prestará especial atención a las variables explicativas más relevantes para las hipótesis planteadas: PIB per cápita, apoyo social, esperanza de vida saludable y libertad para tomar decisiones vitales.
# 4. Las columnas `upperwhisker` y `lowerwhisker` se considerarán secundarias en esta fase, ya que no son centrales para responder a la pregunta principal del proyecto.
# 5. Antes del análisis visual y relacional, será conveniente revisar si existen nulos, posibles duplicados y si resulta útil renombrar columnas para facilitar la lectura del notebook y de las gráficas.
#
# Con estas decisiones, el dataset queda preparado para pasar a una fase de limpieza ligera y organización de variables antes de comenzar el análisis exploratorio en profundidad.

# %% [markdown]
# ## Limpieza ligera y preparación del dataset
#
# Antes de comenzar con el análisis visual y relacional, se realiza una fase de preparación del subconjunto de 2024 para trabajar con un dataframe más limpio, legible y fácil de interpretar.
#
# En esta fase se revisarán posibles duplicados, se seleccionarán las variables más relevantes para el análisis, se renombrarán columnas largas y se construirá una versión simplificada del dataset orientada a la exploración y visualización.

# %%
df_2024.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# La revisión de duplicados permite comprobar si existen filas repetidas dentro del subconjunto de 2024. En caso de no encontrarse duplicados, se podrá continuar con el análisis sin necesidad de eliminar registros por este motivo.

# %%
relevant_columns = [
    'Country name',
    'Rank',
    'Ladder score',
    'Explained by: Log GDP per capita',
    'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity',
    'Explained by: Perceptions of corruption'
]

df_selected = df_2024[relevant_columns].copy()

df_selected.head()
# Out:
#    Country name  Rank  Ladder score  Explained by: Log GDP per capita  \
# 0       Finland     1         7.736                             1.749
# 13      Denmark     2         7.521                             1.825
# 26      Iceland     3         7.515                             1.799
# 45       Sweden     4         7.345                             1.783
# 58  Netherlands     5         7.306                             1.822
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                          1.783                                  0.824
# 13                         1.748                                  0.820
# 26                         1.840                                  0.873
# 45                         1.698                                  0.889
# 58                         1.667                                  0.844
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# ...

# %% [markdown]
# En este punto se seleccionan únicamente las variables más útiles para responder a la pregunta principal del proyecto. Se conserva la puntuación de felicidad como variable objetivo, junto con las principales variables explicativas planteadas en las hipótesis.
#
# Se dejan fuera columnas secundarias como los límites superior e inferior (`upperwhisker` y `lowerwhisker`) y otras variables que no aportan valor directo al análisis principal.

# %%
df_selected = df_selected.rename(columns={
    'Country name': 'country',
    'Rank': 'rank',
    'Ladder score': 'happiness_score',
    'Explained by: Log GDP per capita': 'gdp_per_capita',
    'Explained by: Social support': 'social_support',
    'Explained by: Healthy life expectancy': 'healthy_life_expectancy',
    'Explained by: Freedom to make life choices': 'freedom_of_choice',
    'Explained by: Generosity': 'generosity',
    'Explained by: Perceptions of corruption': 'perception_of_corruption'
})

df_selected.head()
# Out:
#         country  rank  happiness_score  gdp_per_capita  social_support  \
# 0       Finland     1            7.736           1.749           1.783
# 13      Denmark     2            7.521           1.825           1.748
# 26      Iceland     3            7.515           1.799           1.840
# 45       Sweden     4            7.345           1.783           1.698
# 58  Netherlands     5            7.306           1.822           1.667
#
#     healthy_life_expectancy  freedom_of_choice  generosity  \
# 0                     0.824              0.986       0.110
# 13                    0.820              0.955       0.150
# 26                    0.873              0.971       0.201
# 45                    0.889              0.952       0.170
# 58                    0.844              0.860       0.186
#
#     perception_of_corruption
# 0                      0.502
# 13                     0.488
# 26                     0.173
# 45                     0.467
# 58                     0.344

# %% [markdown]
# El renombrado de columnas permite trabajar con nombres más breves, claros y consistentes. Esto facilita la lectura del notebook, simplifica la escritura del código y mejora la presentación de futuras visualizaciones.

# %%
df_clean = df_selected.copy()

df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 147 entries, 0 to 1956
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   147 non-null    str
#  1   rank                      147 non-null    int64
#  2   happiness_score           147 non-null    float64
#  3   gdp_per_capita            147 non-null    float64
#  4   social_support            147 non-null    float64
#  5   healthy_life_expectancy   146 non-null    float64
#  6   freedom_of_choice         146 non-null    float64
#  7   generosity                147 non-null    float64
#  8   perception_of_corruption  146 non-null    float64
# dtypes: float64(7), int64(1), str(1)
# memory usage: 11.5 KB

# %%
df_clean.describe()
# Out:
#              rank  happiness_score  gdp_per_capita  social_support  \
# count  147.000000       147.000000      147.000000      147.000000
# mean    74.000000         5.578170        1.318701        1.333395
# std     42.579338         1.158278        0.393862        0.349952
# min      1.000000         1.364000        0.000000        0.000000
# 25%     37.500000         4.702500        1.037000        1.131000
# 50%     74.000000         5.868000        1.347000        1.438000
# 75%    110.500000         6.479000        1.648000        1.593500
# max    147.000000         7.736000        2.028000        1.840000
#
#        healthy_life_expectancy  freedom_of_choice  generosity  \
# count               146.000000         146.000000  147.000000
# mean                  0.551493           0.749253    0.113442
# std                   0.218802           0.177694    0.059773
# min                   0.000000           0.000000    0.000000
# ...

# %% [markdown]
# A partir de este momento, `df_clean` será el dataframe principal de trabajo para el resto del análisis.
#
# Este nuevo conjunto de datos está centrado en 2024, contiene únicamente las variables más relevantes para el estudio y presenta una estructura más clara para desarrollar análisis univariantes, bivariantes y multivariantes.

# %% [markdown]
# ## Análisis univariante de la felicidad (Bloque descriptivo)
#
# Una vez preparado el dataset, el siguiente paso consiste en explorar cómo se distribuye la puntuación de felicidad entre los países analizados en 2024.
#
# Este bloque permitirá identificar:
# - la distribución general de la variable principal,
# - los países con mayores niveles de felicidad,
# - los países con menores niveles de felicidad,
# - y algunos patrones iniciales que servirán de base para análisis posteriores más profundos.

# %%
df_clean['happiness_score'].describe()
# Out:
# count    147.000000
# mean       5.578170
# std        1.158278
# min        1.364000
# 25%        4.702500
# 50%        5.868000
# 75%        6.479000
# max        7.736000
# Name: happiness_score, dtype: float64

# %% [markdown]
# La puntuación de felicidad en 2024 presenta una variabilidad considerable entre países. Aunque la media se sitúa en 5.58 puntos y la mediana en 5.87, la distancia entre el valor mínimo (1.364) y el máximo (7.736) refleja que existen diferencias muy marcadas en el nivel de bienestar percibido a escala internacional.
#
# El hecho de que la media sea ligeramente inferior a la mediana sugiere una posible asimetría hacia valores bajos, probablemente influida por un grupo reducido de países con puntuaciones especialmente bajas.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_clean['happiness_score'], bins=20, kde=True, color='teal')

plt.title('Distribution of Happiness Score in 2024', fontsize=14)
plt.xlabel('Happiness score')
plt.ylabel('Number of countries')
plt.show()

# %% [markdown]
# La distribución de la felicidad muestra que la mayoría de países se concentra en niveles intermedios, mientras que los valores extremos son menos frecuentes. Sin embargo, la presencia de algunos países con puntuaciones especialmente bajas introduce una cierta asimetría en la distribución.
#
# Esto sugiere que, aunque una parte importante del mundo se mueve en niveles medios de felicidad, existe un grupo reducido de países en situaciones claramente más desfavorables.

# %%
happiest_10 = df_clean.sort_values(by='happiness_score', ascending=False).head(10)

happiest_10[['country', 'happiness_score']]
# Out:
#          country  happiness_score
# 0        Finland            7.736
# 13       Denmark            7.521
# 26       Iceland            7.515
# 45        Sweden            7.345
# 58   Netherlands            7.306
# 71    Costa Rica            7.274
# 84        Norway            7.262
# 97        Israel            7.234
# 109   Luxembourg            7.122
# 122       Mexico            6.979

# %% [markdown]
# Los países con mayor puntuación de felicidad están encabezados por Finlandia, Dinamarca e Islandia. La fuerte presencia de países nórdicos sugiere patrones comunes de bienestar, estabilidad y calidad de vida, aunque la aparición de otros países fuera de esa región indica que la felicidad no responde a un único modelo.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=happiest_10,
    x='happiness_score',
    y='country',
    hue='country',
    palette='viridis',
    legend=False
)

plt.title('Top 10 Happiest Countries in 2024', fontsize=14)
plt.xlabel('Happiness score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# Este ranking permite identificar qué países lideran la clasificación de felicidad en 2024. Además de mostrar las puntuaciones más altas, este resultado servirá más adelante para comparar si los países mejor posicionados comparten también patrones similares en variables como PIB, apoyo social o salud.

# %%
saddest_10 = df_clean.sort_values(by='happiness_score', ascending=True).head(10)

saddest_10[['country', 'happiness_score']]
# Out:
#            country  happiness_score
# 1956   Afghanistan            1.364
# 1943  Sierra Leone            2.998
# 1931       Lebanon            3.188
# 1918        Malawi            3.260
# 1905      Zimbabwe            3.396
# 1892      Botswana            3.438
# 1879      DR Congo            3.469
# 1866         Yemen            3.561
# 1853       Comoros            3.754
# 1840       Lesotho            3.757

# %% [markdown]
# Los países con menor puntuación de felicidad presentan contextos potencialmente más vulnerables desde el punto de vista económico, social o político. Esta parte del ranking será especialmente útil para comparar más adelante qué diferencias presentan respecto a los países con mejores resultados.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=saddest_10,
    x='happiness_score',
    y='country',
    hue='country',
    palette='rocket',
    legend=False
)

plt.title('The 10 unhappiest countries of 2024', fontsize=14)
plt.xlabel('Happiness score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# En la parte baja del ranking aparece Afganistán con la puntuación más reducida del conjunto analizado, seguido de Sierra Leona, Líbano y Malawi. En general, este grupo está formado por países que suelen enfrentarse a contextos más vulnerables desde el punto de vista económico, social o político.
#
# Aunque este análisis todavía no permite establecer relaciones causales, la concentración de puntuaciones bajas en países con mayores dificultades estructurales sugiere que el bienestar percibido podría estar estrechamente vinculado a condiciones de vida menos favorables.

# %%
happiest_saddest = pd.concat([happiest_10, saddest_10])

plt.figure(figsize=(14, 8))
sns.barplot(
    data=happiest_saddest.sort_values(by='happiness_score', ascending=False),
    x='happiness_score',
    y='country',
    hue='country',
    palette='coolwarm',
    legend=False
)

plt.title('Comparison Between the Happiest and Least Happy Countries in 2024', fontsize=15)
plt.xlabel('Happiness score')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# La comparación entre ambos extremos del ranking pone de manifiesto una brecha muy marcada en los niveles de felicidad. Esta diferencia refuerza la necesidad de estudiar qué variables explicativas están más asociadas a los países mejor y peor posicionados.

# %% [markdown]
# ## Análisis bivariante: relación entre felicidad y factores explicativos
#
# Una vez explorada la distribución general de la felicidad y los extremos del ranking, el siguiente paso consiste en analizar cómo se relaciona la puntuación de felicidad con algunas de las variables más relevantes del dataset.
#
# En este bloque se estudiará la relación entre la felicidad y:
# - el PIB per cápita,
# - el apoyo social,
# - la esperanza de vida saludable,
# - y la libertad para tomar decisiones vitales.
#
# El objetivo es comprobar visualmente si existe una asociación positiva entre estas variables y el nivel de felicidad de los países.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_clean,
    x='gdp_per_capita',
    y='happiness_score',
    scatter_kws={'s': 70, 'color': 'steelblue', 'alpha': 0.8},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Happiness Score vs GDP per Capita', fontsize=14)
plt.xlabel('GDP per capita')
plt.ylabel('Happiness score')
plt.show()

# %% [markdown]
# Se observa una relación positiva clara entre PIB per cápita y felicidad, respaldada por una correlación de `0.763`. Los países con mayor nivel económico tienden, en general, a presentar mayores niveles de bienestar percibido.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_clean,
    x='social_support',
    y='happiness_score',
    scatter_kws={'s': 70, 'color': 'seagreen', 'alpha': 0.8},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Happiness Score vs Social Support', fontsize=14)
plt.xlabel('Social support')
plt.ylabel('Happiness score')
plt.show()

# %% [markdown]
# El apoyo social es la variable que muestra la asociación más fuerte con la felicidad (`0.812`). Esto sugiere que contar con una red social sólida es un factor especialmente relevante en el bienestar de los países.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_clean,
    x='healthy_life_expectancy',
    y='happiness_score',
    scatter_kws={'s': 70, 'color': 'darkorange', 'alpha': 0.8},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Happiness Score vs Healthy Life Expectancy', fontsize=14)
plt.xlabel('Healthy life expectancy')
plt.ylabel('Happiness score')
plt.show()

# %% [markdown]
# La esperanza de vida saludable presenta también una relación positiva importante con la felicidad (`0.712`), lo que refuerza la idea de que la salud es una dimensión clave del bienestar.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    data=df_clean,
    x='freedom_of_choice',
    y='happiness_score',
    scatter_kws={'s': 70, 'color': 'purple', 'alpha': 0.8},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Happiness Score vs Freedom of Choice', fontsize=14)
plt.xlabel('Freedom of choice')
plt.ylabel('Happiness score')
plt.show()

# %% [markdown]
# La libertad para tomar decisiones vitales mantiene una asociación positiva con la felicidad (`0.634`), aunque algo menos intensa que otras variables principales del análisis.

# %% [markdown]
# ## Matriz de correlación
#
# Además del análisis visual individual, resulta útil medir de forma conjunta la relación lineal entre las variables numéricas del dataset. Para ello se utilizará una matriz de correlación, que permitirá identificar qué factores presentan una asociación más intensa con la puntuación de felicidad.

# %%
correlation_matrix = df_clean.corr(numeric_only=True)

correlation_matrix
# Out:
#                               rank  happiness_score  gdp_per_capita  \
# rank                      1.000000        -0.972355       -0.779976
# happiness_score          -0.972355         1.000000        0.763269
# gdp_per_capita           -0.779976         0.763269        1.000000
# social_support           -0.772974         0.812122        0.709762
# healthy_life_expectancy  -0.714517         0.711854        0.747131
# freedom_of_choice        -0.603452         0.634400        0.381369
# generosity               -0.061004         0.054351       -0.072993
# perception_of_corruption -0.461632         0.412457        0.384901
#
#                           social_support  healthy_life_expectancy  \
# rank                           -0.772974                -0.714517
# happiness_score                 0.812122                 0.711854
# gdp_per_capita                  0.709762                 0.747131
# social_support                  1.000000                 0.594703
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title('Correlation Matrix', fontsize=14)
plt.show()

# %% [markdown]
# La matriz de correlación permite cuantificar la intensidad y dirección de la relación lineal entre variables.
#
# - Valores cercanos a `1` indican una relación positiva fuerte.
# - Valores cercanos a `-1` indican una relación negativa fuerte.
# - Valores cercanos a `0` indican una relación lineal débil o inexistente.

# %% [markdown]
# La matriz de correlación confirma que la felicidad está asociada positivamente con varias dimensiones del bienestar, especialmente apoyo social, PIB y salud. Esto refuerza la idea de que la felicidad responde a una combinación de factores y no a una única causa aislada.

# %% [markdown]
# En conjunto, el análisis bivariante confirma que las principales hipótesis del proyecto están respaldadas por los datos. Las relaciones más intensas con la felicidad se observan en el apoyo social, el PIB per cápita y la salud, mientras que la libertad también muestra una asociación positiva relevante. Estos resultados sugieren que los países más felices tienden a combinar mejores condiciones económicas, sociales y de calidad de vida.

# %% [markdown]
# ## Análisis multivariante y comparación entre grupos
#
# Después de estudiar la relación individual entre felicidad y varias variables explicativas, resulta útil dar un paso más y analizar cómo se combinan estos factores en los países con mejores y peores resultados.
#
# En esta sección se compararán los países más felices y los menos felices para comprobar si los niveles altos de felicidad tienden a asociarse no con una sola variable, sino con la combinación de varios factores favorables al mismo tiempo.

# %%
top_10_happiest = df_clean.sort_values(by='happiness_score', ascending=False).head(10).copy()
bottom_10_least_happy = df_clean.sort_values(by='happiness_score', ascending=True).head(10).copy()

# %%
comparison_summary = pd.DataFrame({
    'Top 10 happiest': top_10_happiest[
        ['gdp_per_capita', 'social_support', 'healthy_life_expectancy', 'freedom_of_choice']
    ].mean(),
    'Bottom 10 least happy': bottom_10_least_happy[
        ['gdp_per_capita', 'social_support', 'healthy_life_expectancy', 'freedom_of_choice']
    ].mean()
})

comparison_summary
# Out:
#                          Top 10 happiest  Bottom 10 least happy
# gdp_per_capita                    1.7530                 0.8208
# social_support                    1.6852                 0.8315
# healthy_life_expectancy           0.8031                 0.2555
# freedom_of_choice                 0.9184                 0.4777

# %% [markdown]
# La comparación de medias permite resumir cómo se comportan las principales variables explicativas en los dos extremos del ranking de felicidad.
#
# Si los países más felices presentan valores superiores de forma sistemática en varias dimensiones a la vez, esto reforzará la idea de que la felicidad está asociada a una combinación de factores favorables y no a un único elemento aislado.

# %%
comparison_summary.plot(
    kind='bar',
    figsize=(12, 6),
    color=['mediumseagreen', 'indianred']
)

plt.title('Comparison of Key Factors: Top 10 vs Bottom 10 Countries', fontsize=14)
plt.xlabel('Variables')
plt.ylabel('Average value')
plt.xticks(rotation=45)
plt.legend(title='Group')
plt.show()

# %% [markdown]
# Los países más felices presentan valores medios superiores en todas las variables clave analizadas. Esto sugiere que la felicidad no está asociada a un único factor aislado, sino a la combinación de varias condiciones favorables.

# %%
comparison_summary_reset = comparison_summary.reset_index()
comparison_summary_reset.columns = ['variable', 'Top 10 happiest', 'Bottom 10 least happy']

comparison_melted = comparison_summary_reset.melt(
    id_vars='variable',
    var_name='group',
    value_name='mean_value'
)

comparison_melted
# Out:
#                   variable                  group  mean_value
# 0           gdp_per_capita        Top 10 happiest      1.7530
# 1           social_support        Top 10 happiest      1.6852
# 2  healthy_life_expectancy        Top 10 happiest      0.8031
# 3        freedom_of_choice        Top 10 happiest      0.9184
# 4           gdp_per_capita  Bottom 10 least happy      0.8208
# 5           social_support  Bottom 10 least happy      0.8315
# 6  healthy_life_expectancy  Bottom 10 least happy      0.2555
# 7        freedom_of_choice  Bottom 10 least happy      0.4777

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(
    data=comparison_melted,
    x='variable',
    y='mean_value',
    hue='group',
    marker='o',
    linewidth=2.5
)

plt.title('Multivariate Profile: Top 10 vs Bottom 10 Countries', fontsize=14)
plt.xlabel('Variables')
plt.ylabel('Average value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# La comparación de perfiles muestra que el grupo de países más felices mantiene un comportamiento consistentemente superior en todas las dimensiones principales del análisis. Esto refuerza una interpretación multivariante del bienestar.

# %% [markdown]
# ## Comparación detallada de los países más y menos felices
#
# Además de comparar medias grupales, también resulta útil observar cómo se distribuyen las variables clave dentro de cada país de los grupos extremos. Para ello se construye una visualización conjunta que permite detectar patrones comunes entre los países más felices y los menos felices.

# %%
top_bottom_multivariate = pd.concat([
    top_10_happiest.assign(group='Top 10 happiest'),
    bottom_10_least_happy.assign(group='Bottom 10 least happy')
])

heatmap_data = top_bottom_multivariate.set_index('country')[
    ['gdp_per_capita', 'social_support', 'healthy_life_expectancy', 'freedom_of_choice']
]

plt.figure(figsize=(12, 10))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='.2f')

plt.title('Key Factors by Country: Top and Bottom Happiness Groups', fontsize=14)
plt.xlabel('Variables')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# El mapa de calor confirma que el patrón observado a nivel grupal también se repite en buena parte de los países de cada grupo. Los países más felices tienden a concentrar valores altos en varias variables al mismo tiempo.

# %% [markdown]
# ## Validación de la hipótesis multivariante
#
# Los resultados obtenidos en esta sección respaldan la hipótesis de que los países con mayores niveles de felicidad no destacan únicamente en una variable aislada, sino en la combinación de varios factores favorables.
#
# La comparación entre los países más felices y los menos felices muestra que el grupo mejor posicionado presenta, de forma sistemática, valores medios más altos en PIB per cápita, apoyo social, esperanza de vida saludable y libertad para tomar decisiones vitales.
#
# Esto sugiere que la felicidad no debe interpretarse como el resultado de una única causa, sino como la expresión de un contexto más amplio de bienestar económico, social y personal. En consecuencia, los datos apoyan una visión multivariante del fenómeno, donde diferentes dimensiones actúan conjuntamente.

# %% [markdown]
# Los países más felices no destacan por una fortaleza aislada, sino por un perfil global más sólido.

# %% [markdown]
# ## Conclusiones finales
#
# Tras realizar el análisis exploratorio de los datos de felicidad mundial correspondientes a 2024, se observa que la felicidad de los países no parece responder a un único factor aislado, sino a la combinación de varias dimensiones del bienestar.
#
# Los resultados obtenidos muestran que variables como el apoyo social, el PIB per cápita, la esperanza de vida saludable y la libertad para tomar decisiones vitales presentan asociaciones positivas con la puntuación de felicidad. Entre ellas, el apoyo social destaca como la variable más fuertemente relacionada con el bienestar percibido en los países analizados.
#
# Además, la comparación entre los países más felices y los menos felices refuerza la idea de que los contextos con mejores resultados tienden a concentrar simultáneamente mejores condiciones económicas, sociales y de calidad de vida. En consecuencia, la felicidad puede entenderse como un fenómeno multivariante, vinculado a un entorno general más favorable y equilibrado.

# %% [markdown]
# ## Validación de hipótesis
#
# A continuación se revisan las hipótesis planteadas al inicio del proyecto a la luz de los resultados obtenidos:
#
# ### Hipótesis 1
# **Los países con mayor PIB per cápita tienden a presentar mayores niveles de felicidad.**
#
# **Validación:** Confirmada.
# El análisis bivariante mostró una relación positiva clara entre ambas variables, respaldada por una correlación de `0.763`. Esto sugiere que un mayor nivel económico está asociado, en general, con mayores niveles de bienestar percibido.
#
# ### Hipótesis 2
# **El apoyo social es uno de los factores más influyentes en la felicidad de un país.**
#
# **Validación:** Confirmada.
# El apoyo social fue la variable que presentó la asociación más fuerte con la felicidad, con una correlación de `0.812`. Este resultado indica que la percepción de una red de apoyo sólida constituye uno de los elementos más relevantes dentro del bienestar de un país.
#
# ### Hipótesis 3
# **Una mayor esperanza de vida saludable está asociada con una mayor puntuación de felicidad.**
#
# **Validación:** Confirmada.
# La relación entre salud y felicidad fue positiva y significativa, con una correlación de `0.712`. Esto respalda la idea de que unas mejores condiciones de salud están asociadas a mayores niveles de bienestar general.
#
# ### Hipótesis 4
# **Los países con mayor libertad para tomar decisiones vitales tienden a mostrar niveles más altos de felicidad.**
#
# **Validación:** Confirmada.
# La libertad para tomar decisiones vitales mostró también una asociación positiva con la felicidad, con una correlación de `0.634`. Aunque su relación es algo menos intensa que otras variables, sigue siendo claramente relevante.
#
# ### Hipótesis 5
# **Los países con mayores niveles de felicidad no destacan únicamente en una sola variable, sino en la combinación de varios factores favorables, como un mayor PIB per cápita, un fuerte apoyo social y una mejor esperanza de vida saludable.**
#
# **Validación:** Confirmada.
# El análisis multivariante mostró que los países más felices presentan de forma sistemática valores más altos en varias dimensiones al mismo tiempo. Esto refuerza la idea de que la felicidad se relaciona con un perfil general de bienestar, y no con una única fortaleza aislada.

# %% [markdown]
# ## Limitaciones del análisis
#
# Aunque el proyecto permite identificar patrones relevantes, conviene tener en cuenta algunas limitaciones:
#
# 1. El análisis se ha centrado exclusivamente en los datos de 2024, por lo que no recoge la evolución temporal de la felicidad ni de sus factores explicativos.
# 2. Se trata de un análisis exploratorio, por lo que las relaciones observadas deben interpretarse como asociaciones y no como pruebas de causalidad.
# 3. El dataset recoge un conjunto concreto de variables explicativas, pero la felicidad es un fenómeno complejo en el que también pueden intervenir factores culturales, políticos, históricos o sociales no incluidos en este análisis.
# 4. Algunas variables del dataset pueden reflejar percepciones agregadas o indicadores sintéticos, lo que introduce cierto nivel de abstracción en la medición del bienestar.
# 5. El enfoque se ha centrado en comparaciones entre países, por lo que no permite analizar desigualdades internas o diferencias dentro de cada nación.

# %% [markdown]
# ## Recomendaciones y próximos pasos
#
# A partir de este análisis, podrían plantearse varias líneas de continuación:
#
# 1. Incorporar una perspectiva temporal para estudiar cómo ha evolucionado la felicidad en los países a lo largo de varios años.
# 2. Analizar otras variables complementarias que puedan enriquecer la interpretación, como indicadores de empleo, educación, desigualdad o estabilidad política.
# 3. Profundizar en el análisis regional para comparar patrones entre continentes o bloques geográficos.
# 4. Aplicar técnicas estadísticas o de modelización más avanzadas para estimar con mayor precisión el peso relativo de cada factor.
# 5. Explorar segmentaciones o agrupaciones de países con perfiles similares para identificar tipologías de bienestar.
#
# En conjunto, este proyecto muestra que el análisis de la felicidad puede ofrecer información útil para entender mejor qué dimensiones del bienestar parecen estar más asociadas a contextos nacionales más favorables.
